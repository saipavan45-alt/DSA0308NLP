# %%
import nltk
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
nltk.download('punkt')
nltk.download('punkt_tab')

text = input("Enter a paragraph:\n")
sentences = sent_tokenize(text)
if len(sentences) < 2:
    print("Please enter at least two sentences.")
else:
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(sentences)
    similarity_scores = []
    for i in range(len(sentences) - 1):
        score = cosine_similarity(
            tfidf_matrix[i],
            tfidf_matrix[i + 1]
        )[0][0]
        similarity_scores.append(score)
        print("\nSentence", i + 1, ":", sentences[i])
        print("Sentence", i + 2, ":", sentences[i + 1])
        print("Coherence Score:", round(score, 2))
    average_score = sum(similarity_scores) / len(similarity_scores)
    print("\nAverage Coherence Score:", round(average_score, 2))
    if average_score >= 0.3:
        print("Result: The text is reasonably coherent.")
    else:
        print("Result: The text has low coherence.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Enter a paragraph:
# Life is a journey filled with unexpected moments, offering us daily chances to learn and grow. Every challenge we face helps build our inner strength, while moments of joy remind us to appreciate the simple beauty around us. By keeping an open mind and a kind heart, we can turn ordinary experiences into meaningful memories that guide us forward.
#
# Sentence 1 : Life is a journey filled with unexpected moments, offering us daily chances to learn and grow.
# Sentence 2 : Every challenge we face helps build our inner strength, while moments of joy remind us to appreciate the simple beauty around us.
# Coherence Score: 0.11
#
# Sentence 2 : Every challenge we face helps build our inner strength, while moments of joy remind us to appreciate the simple beauty around us.
# Sentence 3 : By keeping an open mind and a kind heart, we can turn ordinary experiences into meaningful memories that guide us forward.
# Coherence Score: 0.07
#
# Average Coherence Score: 0.09
# Result: The text has low coherence.
